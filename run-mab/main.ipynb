# %%
import sys
import pandas as pd 

rumFile = './test.json'
conversionName = 'convert'
conversionValue = ''

if len(sys.argv) > 2:
    rumFile = sys.argv[1]

if len(sys.argv) > 3:
    conversionName = sys.argv[2]
if len(sys.argv) > 4:
    conversionValue = sys.argv[3]


data = pd.read_json(rumFile)

mab_config = []
for url in data:
    data['url'] = url
    for exp in data[url]:
        for variant in exp['variants']:
            variant['experient'] = exp['experiment']
            variant['url'] = url
            mab_config.append(variant)


df = pd.DataFrame(mab_config)
df.tail()
# Out:
#            name  views                                             clicks
# 0  challenger-2   2250  {'.html-snippet': 10, '#lpclose': 140, '.grid-...  \
# 1  challenger-6   2490  {'.grid-overlay': 150, '#lpshroud': 10, '#lpcl...
# 2  challenger-8    730         {'.grid-overlay': 10, '.html-snippet': 10}
# 3  challenger-4    710  {'.html-snippet': 10, '.grid-overlay': 120, '....
# 4       control    130                                                 {}
#
#                                          conversions               experient
# 0  {'shop-m-bodywear': 70, 'shop-m-bras': 10, 'sh...  Hero Copy and CTA Test  \
# 1        {'shop-m-bodywear': 130, 'shop-m-bras': 20}  Hero Copy and CTA Test
# 2                            {'shop-m-bodywear': 10}  Hero Copy and CTA Test
# 3        {'shop-m-bodywear': 20, 'shop-m-bras': 100}  Hero Copy and CTA Test
# 4                                                 {}  Hero Copy and CTA Test
#
#                             url
# ...
